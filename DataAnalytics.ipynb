# %% [markdown]
# <a href="https://colab.research.google.com/github/surazkarn/SocialMediaAnalytics/blob/main/DataAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# read the json file into a dataframe
df = pd.read_json('your_posts_1.json')
df.head(10)
# Out:
#             timestamp                                        attachments  \
# 0 2020-01-15 02:54:53  [{'data': [{'media': {'uri': 'posts/media/your...
# 1 2020-01-15 12:47:29                                                NaN
# 2 2020-02-02 04:05:18                                                 []
# 3 2020-03-31 08:54:34  [{'data': [{'media': {'uri': 'posts/media/Mobi...
# 4 2020-04-01 11:36:51  [{'data': [{'media': {'uri': 'posts/media/Mobi...
# 5 2020-04-02 14:10:12  [{'data': [{'external_context': {'url': 'https...
# 6 2020-04-12 18:25:50  [{'data': [{'media': {'uri': 'posts/media/Mobi...
# 7 2020-04-19 15:28:44  [{'data': [{'media': {'uri': 'posts/media/Mobi...
# 8 2020-04-22 02:54:08  [{'data': [{'media': {'uri': 'posts/media/your...
# 9 2020-04-22 18:10:09                                                 []
#
#                                                 data  \
# 0  [{'post': '!!!Happy birthday Sanjan Sah !!!
# ð...
# 1                                                 []
# 2                 [{'update_timestamp': 1580616318}]
# 3                    [{'post': '#corona
# #lockdown'}]
# 4               [{'post': '#stay home
# #stay safe'}]
# 5                 [{'update_timestamp': 1585836612}]
# 6  [{'post': 'Say good bye to all worries
# It's t...
# 7  [{'post': '#Recalledð¸ Bachpan ð¬
#
# I wish...
# 8  [{'post': 'Happy marriage Anniversary bhaiyaâ...
# 9                 [{'update_timestamp': 1587579009}]
#
#                                                title  \
# 0  Suraz Karn added a new photo to Sajan Sah's ti...
# 1                                                NaN
# 2                          Suraz Karn shared a post.
# 3                                                NaN
# 4                                                NaN
# 5                          Suraz Karn shared a link.
# 6                                                NaN
# 7                                                NaN
# 8  Suraz Karn added a new photo to Rupa Ashok Kar...
# 9                         Suraz Karn shared a video.
#
#                                                 tags
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'name': 'Bhaskar Karn'}, {'name': 'Paridhi K...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                         [{'name': 'Bhaskar Karn'}]
# 8  [{'name': 'Rupa Ashok Karn'}, {'name': 'Ashok ...
# 9                                                NaN

# %%
# rename the timestamp column
df.rename(columns={'timestamp': 'date'}, inplace=True)

#drop some unnecessary columns
df = df.drop(['attachments', 'title', 'tags'], axis=1)

# making sure it's datetime format
pd.to_datetime(df['date'])

df.head(10)
# Out:
#                  date                                               data
# 0 2020-01-15 02:54:53  [{'post': '!!!Happy birthday Sanjan Sah !!!
# ð...
# 1 2020-01-15 12:47:29                                                 []
# 2 2020-02-02 04:05:18                 [{'update_timestamp': 1580616318}]
# 3 2020-03-31 08:54:34                    [{'post': '#corona
# #lockdown'}]
# 4 2020-04-01 11:36:51               [{'post': '#stay home
# #stay safe'}]
# 5 2020-04-02 14:10:12                 [{'update_timestamp': 1585836612}]
# 6 2020-04-12 18:25:50  [{'post': 'Say good bye to all worries
# It's t...
# 7 2020-04-19 15:28:44  [{'post': '#Recalledð¸ Bachpan ð¬
#
# I wish...
# 8 2020-04-22 02:54:08  [{'post': 'Happy marriage Anniversary bhaiyaâ...
# 9 2020-04-22 18:10:09                 [{'update_timestamp': 1587579009}]

# %%
# rename the timestamp column
df.rename(columns={'timestamp': 'date'}, inplace=True)

# %%
df.head(10)
# Out:
#                  date                                               data
# 0 2020-01-15 02:54:53  [{'post': '!!!Happy birthday Sanjan Sah !!!
# ð...
# 1 2020-01-15 12:47:29                                                 []
# 2 2020-02-02 04:05:18                 [{'update_timestamp': 1580616318}]
# 3 2020-03-31 08:54:34                    [{'post': '#corona
# #lockdown'}]
# 4 2020-04-01 11:36:51               [{'post': '#stay home
# #stay safe'}]
# 5 2020-04-02 14:10:12                 [{'update_timestamp': 1585836612}]
# 6 2020-04-12 18:25:50  [{'post': 'Say good bye to all worries
# It's t...
# 7 2020-04-19 15:28:44  [{'post': '#Recalledð¸ Bachpan ð¬
#
# I wish...
# 8 2020-04-22 02:54:08  [{'post': 'Happy marriage Anniversary bhaiyaâ...
# 9 2020-04-22 18:10:09                 [{'update_timestamp': 1587579009}]

# %%
print(df.shape)
# Out:
# (153, 2)

# %%
df.tail(4)
# Out:
#                    date                                               data
# 149 2022-08-31 09:05:09                 [{'update_timestamp': 1661936709}]
# 150 2022-10-24 17:18:36        [{'post': '#Diwali #Bhubaneswar #friends'}]
# 151 2022-12-02 18:35:24  [{'post': 'Happy Birthday Bhai !
# God bless you...
# 152 2022-12-02 18:38:15  [{'post': 'Happy Birthday Bhai ð!
# Many many...

# %%
df=df.set_index('date')

# %%
post_counts=df['data'].resample('MS').size()
post_counts
# Out:
# date
# 2020-01-01     2
# 2020-02-01     1
# 2020-03-01     1
# 2020-04-01     8
# 2020-05-01     5
# 2020-06-01    44
# 2020-07-01    12
# 2020-08-01    11
# 2020-09-01     8
# 2020-10-01    13
# 2020-11-01    10
# 2020-12-01     8
# 2021-01-01     6
# 2021-02-01     1
# 2021-03-01    10
# 2021-04-01     2
# 2021-05-01     2
# 2021-06-01     1
# 2021-07-01     2
# 2021-08-01     0
# 2021-09-01     0
# 2021-10-01     0
# 2021-11-01     1
# 2021-12-01     0
# 2022-01-01     0
# 2022-02-01     0
# 2022-03-01     0
# 2022-04-01     0
# 2022-05-01     0
# 2022-06-01     1
# 2022-07-01     0
# 2022-08-01     1
# 2022-09-01     0
# 2022-10-01     1
# 2022-11-01     0
# 2022-12-01     2
# Freq: MS, Name: data, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# set figure size and font size
sns.set(rc={'figure.figsize':(20,10)})
sns.set(font_scale=2)

# set x labels
x_labels = post_counts.index

#create bar plot
sns.barplot(x_labels,post_counts, color="blue")

# only show x-axis labels for Jan 1 of every other year
tick_positions = np.arange(10,len(x_labels), step=12)

#reformat date to display year onlyplt.ylabel("post counts")
plt.xticks(tick_positions, x_labels[tick_positions].strftime("%Y"))

# display the plot
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
